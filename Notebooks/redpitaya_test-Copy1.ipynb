# %%
from LFC.Hardware import *
import numpy as np
fg = FG('rp-f0602c.local')
rp_fc = RedPitaya('rp-f072a9.local')
fg.connect()
rp_fc.connect()
fin = lambda x: np.mean(rp_fc.acquire(port = 1))
fout = lambda y: rp_fc.dc(port = 2, offset = y)
fc_lock = Servo(fin, fout, name = 'Filter Cavity lock')
# Out:
# Error:<class 'TimeoutError'>
# Error:<class 'TimeoutError'>

# %%
fg = FG('rp-f072ec.local')
fg.connect()
# Out:
# Filter cavity lock loop FPGA rp-f072ec.local connected
# 1

# %%
# rp_fc = RedPitaya('rp-f072a9.local')
rp_fc = RedPitaya('131.215.238.102')

rp_fc.connect()

# %%
t=1
# Out:
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "C:\Users\HSFLFC\.conda\envs\lfc\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\HSFLFC\.conda\envs\lfc\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\HSFLFC\OneDrive - California Institute of Technology (1)\Vahala Group\Maodong\Projects\Keck\Keck Comb\LFC\Hardware\RedPitaya.py", line 81, in osc
#     y = self.acquire(port)
#   File "C:\Users\HSFLFC\OneDrive - California Institute of Technology (1)\Vahala Group\Maodong\Projects\Keck\Keck Comb\LFC\Hardware\RedPitaya.py", line 58, in acquire
#     if self.read() == 'TD':
#   File "C:\Users\HSFLFC\OneDrive - California Institute of Technology (1)\Vahala Group\Maodong\Projects\Keck\Keck Comb\LFC\Hardware\RedPitaya.py", line 28, in read
#     return self.inst.rx_txt()
#   File "C:\Users\HSFLFC\OneDrive - California Institute of Technology (1)\Vahala Group\Maodong\Projects\Keck\Keck Comb\LFC\Hardware\RedPitaya.py", line 311, in rx_txt
#     chunk = self._socket.recv(chunksize + len(self.delimiter)).decode(
# socket.timeout: timed out

# %%
rp_fc.startosc(port = 1)
rp_fc.setosc(dec = 2**10, xlim = None, ylim = (-10,10), trigger = "NOW")

# %%
rp_fc.stoposc()

# %%
fg.startfg(phase = 0)
rp_fc.ramp(port=2)

# %%
fg.stopfg()
rp_fc.disable(port=2)

# %%
fc_lock.tune(P=1e-3, I =0.01, dt = 0)
fc_lock.start(3,0.3,[-1,1])

# %%
fc_lock.monitor = True
# Out:
# Locked:False, x:1.6666618892153338, y:0.417731425560286

# %%
fclock.stop()
# Out:
# Filter Cavity lock stoped
# Locked:False, x:4.419153771728304, y:0.4163164967792917
