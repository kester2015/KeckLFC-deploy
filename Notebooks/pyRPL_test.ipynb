# %%
from pyrpl import Pyrpl
HOSTNAME = "rp-f072ec.local"
p = Pyrpl(hostname=HOSTNAME,sshport="22")
# Out:
# INFO:pyrpl:Please select or create a configuration file in the file selector window!
# INFO:pyrpl:All your PyRPL settings will be saved to the config file
#     C:/Users/HSFLFC/pyrpl_user_dir/config\example_filename.yml
# If you would like to restart PyRPL with these settings, type "pyrpl.exe example_filename" in a windows terminal or
#     from pyrpl import Pyrpl
#     p = Pyrpl('example_filename')
# in a python terminal.
# ---------------------------------------------------------------------------
# AuthenticationException                   Traceback (most recent call last)
# File ~\.conda\envs\lfc\lib\site-packages\pyrpl\redpitaya.py:223, in RedPitaya.start_ssh(self, attempt)
#     221 try:
#     222     # start ssh connection
# --> 223     self.ssh = SshShell(hostname=self.parameters['hostname'],
#     224                         sshport=self.parameters['sshport'],
#     225                         user=self.parameters['user'],
# ...

# %%
# import pyrpl library
import pyrpl

# create a Pyrpl object and store the configuration in a file 'example_filename.yml'
# by default, the parameter 'gui' is set to True
p = pyrpl.Pyrpl(config='example_filename')

# p = pyrpl.Pyrpl('global_config')
# Out:
# INFO:pyrpl:All your PyRPL settings will be saved to the config file
#     C:\Users\HSFLFC\pyrpl_user_dir\config\example_filename.yml
# If you would like to restart PyRPL with these settings, type "pyrpl.exe example_filename" in a windows terminal or
#     from pyrpl import Pyrpl
#     p = Pyrpl('example_filename')
# in a python terminal.
# ---------------------------------------------------------------------------
# AuthenticationException                   Traceback (most recent call last)
# File ~\.conda\envs\lfc\lib\site-packages\pyrpl\redpitaya.py:223, in RedPitaya.start_ssh(self, attempt)
#     221 try:
#     222     # start ssh connection
# --> 223     self.ssh = SshShell(hostname=self.parameters['hostname'],
#     224                         sshport=self.parameters['sshport'],
#     225                         user=self.parameters['user'],
#     226                         password=self.parameters['password'],
#     227                         delay=self.parameters['delay'],
# ...
