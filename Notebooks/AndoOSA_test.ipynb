# %%
import numpy as np
from LFC.Hardware.AndoOSA_AQ6315E import AndoOSA_AQ6315E
osa = AndoOSA_AQ6315E()
osa.connect()
# Out:
# ANDO AQ-6315E Optical Spectrum Analyzer connected
# 1

# %%
osa.wlcenter = 1560
osa.wlspan = 15
# Out:
# ANDO AQ-6315E Optical Spectrum Analyzer: Scan start wavelength set to 1552.50 nm.
# ANDO AQ-6315E Optical Spectrum Analyzer: Scan stop wavelength set to 1567.50 nm.
# ANDO AQ-6315E Optical Spectrum Analyzer: Scan center wavelength set to 1560.00 nm.
# ANDO AQ-6315E Optical Spectrum Analyzer: Scan start wavelength set to 1552.50 nm.
# ANDO AQ-6315E Optical Spectrum Analyzer: Scan stop wavelength set to 1567.50 nm.
# ANDO AQ-6315E Optical Spectrum Analyzer: Scan span wavelength set to 15.00 nm.

# %%
osa.save_trace('b',
               r"Z:\Maodong\Projects\Keck\Filter Cavity test\20220811-changeFC_T_and_V\Cavity_output_FCT_20.09C_FCV_0V_RioT_22.79C", 
               extensions='.mat')
# Out:
# Z:\Maodong\Projects\Keck\Keck Comb\LFC\Hardware\AndoOSA_AQ6315E.py:253: UserWarning: ANDO AQ-6315E Optical Spectrum Analyzer: To save Filename Z:\Maodong\Projects\Keck\Filter Cavity test\20220811-changeFC_T_and_V\Cavity_output_FCT_20.09C_FCV_0V_RioT_22.79C.mat already exists. Previous file renamed.
#   warnings.warn(self.devicename+": To save Filename "+filename+ext+" already exists. Previous file renamed.")
# ANDO AQ-6315E Optical Spectrum Analyzer: Trace B data is collected and is shown in the plot.
# ANDO AQ-6315E Optical Spectrum Analyzer: Trace B data is saved to Z:\Maodong\Projects\Keck\Filter Cavity test\20220811-changeFC_T_and_V\Cavity_output_FCT_20.09C_FCV_0V_RioT_22.79C.mat

# %%
osa.Single()
# Out:
# ANDO AQ-6315E Optical Spectrum Analyzer: Spectrum collection SINGLE run start.

# %%
export_array = numpy.array(images) #Create an array from a list of images
print export_array.shape ## (10, 256, 256)

hdu = fits.PrimaryHDU(export_array)
hdulist = fits.HDUList([hdu])
hdulist.writeto(out_file_name)
hdulist.close()

# %%
osa.query('RESLN?')
# Out:
# '0.05'

# %%
(wl,po)=osa.get_trace('a')
# Out:
# ANDO AQ-6315E Optical Spectrum Analyzer: Trace A data is collected and is shown in the plot.

# %%
import csv

# %%
t1,t2 = os.path.split(r"Z:\Maodong\Projects\Keck\Filter Cavity test\20220810-changeFC_T_and_V\comb_input.mat")

# %%
r"Z:\Maodong\Projects\Keck\Filter Cavity test\20220810-changeFC_T_and_V\comb_input.mat"[:-4]
# Out:
# 'Z:\\Maodong\\Projects\\Keck\\Filter Cavity test\\20220810-changeFC_T_and_V\\comb_input'

# %%
os.path.isfile(r"Z:\Maodong\Projects\Keck\Filter Cavity test\20220810-changeFC_T_and_V\comb_input.mat")
# Out:
# True

# %%
f"{2:.2f}"
# Out:
# '2.00'

# %%
osa.query('REFL?')
# Out:
# '-20.5'
